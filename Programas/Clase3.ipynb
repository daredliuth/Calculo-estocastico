# %%
p = 0.5
q = 0.5

s0 = 4

s1H = 8
s1T = 2

s2HH = 16

s2HT = 4
s2HT = 4

s3HHH = 32

s3HHT = 8
s3HTH = 8
s3THH = 8

s3HTT = 2
s3THT = 2
s3TTH = 2

s3TTT = 0.5

# %%
e2H = (p * s3HHH) + (q * s3HHT)
e2H
# Out:
# 20.0

# %%
e2T = (p * s3HTH) + (q * s3HTT)
e2T
# Out:
# 5.0

# %%
e1H = (p * e2H) + (q * e2T)
e1H
# Out:
# 12.5

# %%
e2H = (p * s3THH) + (q * s3THT)
e2H
# Out:
# 5.0

# %%
e2T = (p * s3TTH) + (q * s3TTT)
e2T
# Out:
# 1.25

# %%
e1T = (p * e2H) + (q * e2T)
e1T
# Out:
# 3.125
