# %% [markdown]
# # Clase 1

# %% [markdown]
# ## Bibliotecas

# %%
import math

# %%
s0 = 4
u = 2
d = 1/2
r = 1/4
k = 5
x0 = 1.2
delta0 = 1/2

#Establecemos los precios en caso de head y tail.
sH = 8
sT = 2

prestamo = x0 - delta0
prestamo
# Out:
# 0.7

# %% [markdown]
# ## Cálculo del interés del préstamo.

# %%
interes = (1+r) * (x0 - (delta0 * s0))
interes
# Out:
# -1.0

# %% [markdown]
# ## Cálculo del valor para Head

# %%
x1H = (delta0 * sH) + interes
x1H
# Out:
# 3.0

# %% [markdown]
# ## Cálculo del valor para Tail

# %%
x1T = (delta0 * sT) + interes
x1T
# Out:
# 0.0

# %% [markdown]
# ## Probando con x0 = 1.21

# %%
x0 = 1.21
# Cálculo del interés.
interes = (1+r) * (x0 - (delta0 * s0))

#Cálculo para Head
x1H = (delta0 * sH) + interes

#Cálculo para Tail
x1T = (delta0 * sT) + interes

# %%
interes
# Out:
# -0.9875

# %%
x1H
# Out:
# 3.0125

# %%
x1T
# Out:
# 0.012499999999999956

# %% [markdown]
# ## Probando con x0 = 1.19

# %%
x0 = 1.19
# Cálculo del interés.
interes = (1+r) * (x0 - (delta0 * s0))

#Cálculo para Head
x1H = (delta0 * sH) + interes

#Cálculo para Tail
x1T = (delta0 * sT) + interes

# %%
interes
# Out:
# -1.0125000000000002

# %%
x1H
# Out:
# 2.9875

# %%
x1T
# Out:
# -0.012500000000000178
